# %%
import matplotlib.pyplot as plt
import json

# %%
with open('./log/final/onlyStance/50w2v-64s2v-0.5dropout-0.001000weight.json', 'r') as f:
# with open('./log/final/onlyStance/25w2v-64s2v-0.2dropout-0.000100weight.json', 'r') as f:
    content = f.read()
status = json.loads(content)

# %%
epoch = [i for i in range(1, len(status['trainStanceF1']) + 1)]
train = status['trainStanceF1']
testX = [i * 5 for i in range(1, len(status['testStanceF1']) + 1)]
test = status['testStanceF1']

# %%
plt.plot(epoch, train)
plt.plot(testX, test)
